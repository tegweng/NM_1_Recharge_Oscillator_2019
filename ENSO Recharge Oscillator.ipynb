# %% [markdown]
# # Project 1 - Coupled Ocean Recharge Oscillator Model for ENSO

# %% [markdown]
# ## Problem Description

# %% [markdown]
# ## Time Scheme
#
# From computation of the stability dependencies of the analytical model we know that for values of $\mu = 2/3$ with a frequency of $\omega_c = \sqrt{3/32}$ we expect stable, neutral solutions of the recharge-oscillator model.
#
# We can see in the example below that the Euler scheme is unstable for the recharge oscillator with these values, so it is not a suitable time scheme for this problem. The time-step used is 1 day (non-dimensionalised and converted into months). If it were stable we would see a regular pattern

# %%
from main import *
# Out:
# [  1.50000000e-01   1.47563469e-01   1.45166420e-01 ...,  -3.71716540e-06
#   -3.70150881e-06  -3.68591813e-06]
# [  0.00000000e+00  -7.74604352e-06  -1.53340426e-05 ...,  -3.60856312e-06
#   -3.59336058e-06  -3.57822209e-06]

# %% [markdown]
# ## Problem A
#
# We would like to use the Runge-Kutta time scheme for this problem because it is fourth-order accurate. We can also see from the analysis that we can use longer time steps (expand).

# %%
q,t = RK4()

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5,  q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for stable, neutral solution run for 1 period")
plt.show()

# %% [markdown]
# ## Problem B

# %%
q,t = RK4(nop = 5, mew_wac = 0.5)

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for stable, decreasing solution run for 1 period")
plt.show()

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for stable, decreasing solution run for 1 period")
plt.show()

# %%
q, t = RK4(mew_wac = 0.9)

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for increasing solution run for 1 period")
plt.show()

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for increasing decreasing solution run for 1 period")
plt.show()

# %% [markdown]
# ## Task C

# %%
q,t = RK4(eps = 0.1)

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for solution with non-linearity run for 1 period")
plt.show()

# %%
q,t = RK4(nop = 5, eps = 0.1, mew_wac = 0.9)

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for increasing solution run for 1 period")
plt.show()

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for increasing decreasing solution run for 1 period")
plt.show()

# %% [markdown]
# ## Task D

# %%
q,t = RK4(eps = 0.1, ac = "yes")

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for annual frequency solution run for 1 period")
plt.show()

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for annual frequency solution run for 1 period")
plt.show()

# %% [markdown]
# ## Task E

# %%
q,t = RK4(eps = 0.1, ac = "no", wsf = "yes")

plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for annual frequency solution run for 1 period")

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for annual frequency solution run for 1 period")
plt.show()

# %%
q,t = RK4(eps = 0.1, ac = "yes", wsf = "yes")

plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for annual frequency solution run for 1 period")

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for annual frequency solution run for 1 period")
plt.show()

# %% [markdown]
# ## Task F
