# %% [markdown]
# # Project 1 - Coupled Ocean Recharge Oscillator Model for ENSO

# %% [markdown]
# ## Problem Description

# %% [markdown]
# ## Time Scheme
#
# From computation of the stability dependencies of the analytical model we know that for values of $\mu = 2/3$ with a frequency of $\omega_c = \sqrt{3/32}$ we expect stable, neutral solutions of the recharge-oscillator model.
#
# We can see in the example below that the Euler scheme is unstable for the recharge oscillator with these values, so it is not a suitable time scheme for this problem. The time-step used is 1 day (non-dimensionalised and converted into months). If it were stable we would see a regular pattern

# %%
from main import *

q,t = euler()

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5,  q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for stable solution run for 1 period in Euler Time Scheme")
plt.show()

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for stable solution run for 1 period in Euler Time scheme")
plt.show()

# %% [markdown]
# ## Problem A
#
# We would like to use the Runge-Kutta time scheme for this problem because it is fourth-order accurate. We can also see from the analysis that we can use longer time steps (expand).

# %%
q,t = RK4()

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5,  q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for stable, neutral solution run for 1 period")
plt.show()

# %% [markdown]
# ## Problem B

# %%
q,t = RK4(nop = 5, mew_wac = 0.6)

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for stable, decreasing solution run for 5 period")
plt.show()

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for stable, decreasing solution run for 5 period")
plt.show()

# %%
q, t = RK4(nop = 5, mew_wac = 0.7)

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for increasing solution run for 5 periods")
plt.show()

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for increasing decreasing solution run for 5 periods")
plt.show()

# %% [markdown]
# ## Task C

# %%
q,t = RK4(nop = 5, eps = 0.1)

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for solution with non-linearity run for 5 periods")
plt.show()

# %% [markdown]
# However, while non-linearity does

# %%
q,t = RK4(nop = 5, eps = 0.1, mew_wac = 0.7)

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for increasing solution run for 1 period")
plt.show()

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for increasing decreasing solution run for 1 period")
plt.show()

# %% [markdown]
# ## Task D

# %%
q,t = RK4(eps = 0.1, ac = "yes")

fig = plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for annual frequency solution run for 1 period")
plt.show()

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for annual frequency solution run for 1 period")
plt.show()

# %% [markdown]
# ## Task E
#
# First we see the effect of the wind stress forcing on the case where $\mu = 2/3$. We can see that turning this parameter on adds a degree of variability

# %%
q,t = RK4(wsf = "yes")

plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for annual frequency solution run for 1 period")

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for annual frequency solution run for 1 period")
plt.show()

# %% [markdown]
# If we now compare the case where we have included non-linearity, annual variation and wind stress forcing we can see that...

# %%
q,t = RK4(eps = 0.1, ac = "yes", wsf = "yes")

plt.figure()
l1 = plt.plot(q[0,:] * 7.5, q[1,:] * 150,  'b-')
plt.xlabel('T in K')
plt.ylabel('h in m')
plt.title("h-T diagram for annual frequency solution run for 1 period")

fig = plt.figure()
l1 = plt.plot(t * 2, q[0,:]* 7.5,  'b-')
plt.xlabel('Time in months')
plt.ylabel('T in K')
plt.title("t-T diagram for annual frequency solution run for 1 period")
plt.show()

# %% [markdown]
# ## Task F
